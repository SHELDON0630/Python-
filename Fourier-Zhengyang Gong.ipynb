# %% [markdown]
# # Fast Fourier Transform and Recognizing Sample Data of Instruments
# ## Zhengyang Gong Date/10/02/2020
# ### Introduction: This file mainly introduces the use of Fast Fourier Transform to discrete data points and use it the recognize the pitch of sample data.
# 1.Import the basic functions

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Define x and f(x) so that $f(x) = +1$ for $0 \leq x < 0.5$ and $-1$ for $0.5 \leq x < 1$ [1]

# %%
x=np.linspace(0,1,1000)
f1=np.ones(500)       # define f1 an array of 500 1s. 
f2=np.linspace(-1,-1,500)  # define f2 as an array of 500 -1s. 
f=np.append(f1,f2)   # Add the two array together to create an array with 500 1 and 500 -1.

# %% [markdown]
# 3. Plot the graph of x and f(x) and the Fourier coefficient using FFT.

# %%
c_fft = np.fft.rfft(f) # transform the original data using Fast Fourier transform
                       # note the form of the call -
                       # we're using the numpy rfft routine in the numpy fft submodule
plt.figure()
plt.plot(x,f)
plt.title("Orignial data of x and f(x)")
plt.xlabel('x')
plt.ylabel('f(x)');
plt.figure()
plt.xlim(0,500)  #limit xaxis to 500 due to only 500 points
plt.plot(abs(c_fft))   # plot the absolute coefficients
plt.title("Fourier transform of square wave above ")
plt.xlabel('k')
plt.ylabel('coefficient $c_k$');
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
#  4.  Define another square wave and plot the graph with its Fourier Transform coefficient with $0\leq x \leq 1000$, with $f(x) = +1$ for $0 \leq x \leq 10$[2]

# %%
x1=np.linspace(0,1000,1000)
f1new=np.ones(10)
f2new=np.zeros(990)
fnew=np.append(f1new,f2new)

# %%
c_fftnew = np.fft.rfft(fnew) # transform the original data using Fast Fourier transform
                       # note the form of the call -
                       # we're using the numpy rfft routine in the numpy fft submodule
plt.figure()
plt.plot(x1,fnew)
plt.title("Orignial data of x and f(x)")
plt.xlabel('x')
plt.ylabel('f(x)');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xlim(0,500)#limit xaxis to 500 due to only 500 points
plt.plot((c_fftnew.real))   # use the real value 
plt.title("Fourier transform of square wave x and f(x) above ")
plt.xlabel('k')
plt.ylabel('coefficient $c_k$');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 5. Import sample D and draw the grphs about sample D. Calculate the pitch of D using FFT.

# %%
sampleD = np.loadtxt("Sample_D.txt",float)
plt.figure()
plt.plot(sampleD[0:2000]) # Plot the first 2000 data points of D 
plt.title('First 2000 sample data D' )
plt.xlabel('sample points')
plt.ylabel('Frequency(Hz)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Frequency(Hz)')

# %%
plt.figure()
plt.plot(sampleD[::500])
plt.title('Every 500 points sample data D' )
plt.xlabel('sample points')
plt.ylabel('Frequency(Hz)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Frequency(Hz)')

# %%
c_fftD = np.fft.rfft(sampleD) # transform the original data using Fast Fourier Transform 
                       # note the form of the call -
                       # we're using the numpy rfft routine in the numpy fft submodule

plt.figure()
plt.plot(c_fftD[0:10000].real)   # plot the first 10000 real Fourier coefficients
plt.title("Fourier transform of 'sample D '")
plt.xlabel('k')
plt.ylabel('coefficient $c_k$');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
freD= 44.1*1000*590/len(sampleD)
print('The ferquency for sample D is', freD, 'Hz, with the fundamental k in the graph is',590,'which is C4' )
# Out:
# The ferquency for sample D is 260.19 Hz, with the fundamental k in the graph is 590 which is C4

# %% [markdown]
# For Sample D, the Graph of the first 2000 points is a bit clearer than the others. The every 500th points graph shows a clear periodic characters. The fourier transfrom coefficient has relative less peak than the others. All the graphs are smooth.
# 6. Import sample G and draw the grphs about sample G. Calculate the pitch of G using FFT.

# %%
sampleG = np.loadtxt("Sample_G.txt",float)
# Plot the first 2000 data points of G
plt.figure()
plt.plot(sampleG[0:2000])
plt.title('First 2000 sample data G' )
plt.xlabel('sample points')
plt.ylabel('Frequency(Hz)')
#plot every 500 points in G 
plt.figure()
plt.plot(sampleG[::500])
plt.title('Every 500 points sample data G' )
plt.xlabel('sample points')
plt.ylabel('Frequency(Hz)')
# plot the first 10000 Fourier coefficient 
c_fftG = np.fft.rfft(sampleG) # transform the original data using Fast Fourier Transform 
                       # note the form of the call -
                       # we're using the numpy rfft routine in the numpy fft submodule

plt.figure()
plt.plot(c_fftG[0:10000].real)   # plot the first 10000 real Fourier coefficients
plt.title("Fourier transform of 'sample G '")
plt.xlabel('k')
plt.ylabel('coefficient $c_k$');
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
freG= 44.1*1000*1330/len(sampleG)
print('The ferquency for sample G is', freG, 'Hz, with the fundamental k in the graph is',1330,'which is D5 ')
# Out:
# The ferquency for sample G is 586.53 Hz, with the fundamental k in the graph is 1330 which is D5

# %% [markdown]
# The every 500th point graph shows a little bit of perodic characteristics but it's not clear what the period is. The fourier transform coeffiecient shows a wide range of peaks.
# 7. Import sample J and draw the grphs about sample J. Calculate the pitch of J using FFT.

# %%
sampleJ = np.loadtxt("Sample_J.txt",float)
# Plot the first 2000 data points of G
plt.figure()
plt.plot(sampleJ[0:2000])
plt.title('First 2000 sample data J' )
plt.xlabel('sample points')
plt.ylabel('Frequency(Hz)')
#plot every 500 points in J 
plt.figure()
plt.plot(sampleJ[::500])
plt.title('Every 500 points sample data J' )
plt.xlabel('sample points')
plt.ylabel('Frequency(Hz)')
# plot the first 10000 Fourier coefficient 
c_fftJ = np.fft.rfft(sampleJ) # transform the original data using Fast Fourier Transform 
                       # note the form of the call -
                       # we're using the numpy rfft routine in the numpy fft submodule

plt.figure()
plt.plot(c_fftJ[0:10000].real)   # plot the first 10000 real Fourier coefficients
plt.title("Fourier transform of 'sample J '")
plt.xlabel('k')
plt.ylabel('coefficient $c_k$');
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
freJ= 44.1*1000*880/len(sampleJ)
print('The ferquency for sample J is', freJ, 'Hz, with the fundamental k in the graph is',880,'which is G4')
# Out:
# The ferquency for sample J is 388.08 Hz, with the fundamental k in the graph is 880 which is G4

# %% [markdown]
#  For the First 2000 points graph, J sample has a little characteristics of period. The fourier transform coefficient graph shows more peaks with wider range of k.
#  [1][2]# PHAS0029 Session 9:The  Discrete Fourier Transform and Fast Fourier Transform, louise.dash@ucl.ac.uk, 06.02.2020
